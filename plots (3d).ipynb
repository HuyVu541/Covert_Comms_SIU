# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import gamma, gammainc
import math
import pickle
from scipy.spatial.distance import cdist
import plotly.graph_objects as go

# %%
def path_loss(d, f=2.4): # d is in kilometre
    return 20 * np.log10(d) + 20 * np.log10(f) + 92.45

def convert_dBm_W(P):
    return 10**((P-30) / 10)

def convert_dB_W(P):
    return 10**((P) / 10)

def watts_to_dB(P):
    return 10 * np.log10(P)

# %%
def cdf_helper(coef, sigmas, m_source, m_relay, relay_num, tau, beta_min):
    P_detection_cdf = 1 - (coef * sum([sigmas[k] * gammainc((m_source + m_relay * relay_num) + k, tau/beta_min) for k in range(len(sigmas))]))
    return P_detection_cdf

# %%
noise = 1e-13
h_uu = 1e-2
rho = 1
tau = 1
relay_num = 5 #5, 10, 20, 30
uav_h = 10

# %%
from adjustText import adjust_text  # Import adjustText library

def generate_map(relay_num, random_seed=100):
    # Fixed points
    source = np.array([[0, 0]])
    destination = np.array([[100, 100]])

    # Parameters
    map_size = 120  # Map boundary

    # Generate unique random seed for each relay based on its index
    np.random.seed(random_seed)  # Set base seed for reproducibility
    relay_points = []

    uav_point = np.random.rand(1, 2) * map_size
    
    for i in range(relay_num):
        # Set each relay's seed based on its index
        np.random.seed(random_seed + 1 + i)
        relay_points.append(np.random.rand(1, 2) * map_size)
    
    relay_points = np.vstack(relay_points)

    # Combine all points
    all_points = np.vstack([source, relay_points, uav_point, destination])
    labels = ['Source'] + [f'Relay{i+1}' for i in range(relay_num)] + ['UAV', 'Destination']

    # Plot
    plt.figure(figsize=(8, 8))
    plt.scatter(source[:, 0], source[:, 1], c='green', label='Source', marker='s', s=100)
    plt.scatter(destination[:, 0], destination[:, 1], c='red', label='Destination', marker='s', s=100)
    plt.scatter(relay_points[:, 0], relay_points[:, 1], c='blue', label='Relays', marker='o')
    plt.scatter(uav_point[:, 0], uav_point[:, 1], c='orange', label='UAV', marker='^', s=100)

    # Annotate with dynamic label adjustment
    texts = []
    for i, (x, y) in enumerate(all_points):
        text = plt.text(x + 1, y + 1, labels[i], fontsize=9)
        texts.append(text)
    
    # Use adjustText to adjust the positions of the labels
    adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

    plt.xlim(-10, map_size + 10)
    plt.ylim(-10, map_size + 10)
    plt.grid(True)

    # Place the legend in the top-right corner
    plt.legend(loc='upper right', fontsize=10)

    plt.title('Map of Source, Relays, UAV, and Destination')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()

    dist_matrix = cdist(all_points, all_points)

    idx_source = 0
    idx_relays_start = 1
    idx_relays_end = idx_relays_start + relay_num
    idx_uav = idx_relays_end
    idx_destination = idx_uav + 1

    # Extract required distances
    d_s_ri = dist_matrix[idx_source, idx_relays_start:idx_relays_end]      # Source to each relay
    d_u_ri = (np.array(dist_matrix[idx_uav, idx_relays_start:idx_relays_end])**2 + uav_h**2)**0.5         # UAV to each relay
    d_ri_u = d_u_ri
    d_ri_d = dist_matrix[idx_relays_start:idx_relays_end, idx_destination] # Each relay to Destination
    d_u_s = (dist_matrix[idx_uav, idx_source]**2 + uav_h**2)**0.5                               # UAV to Source
    d_u_d = (dist_matrix[idx_uav, idx_destination]**2 + uav_h**2)**0.5    

    n = relay_num + 1
    
    pl_s_u = path_loss(d_u_s)                          # Path loss from source to UAV
    pl_ri_u = np.array([path_loss(d) for d in d_ri_u])
    pl_u_ri = pl_ri_u
    pl_s_ri = np.array([path_loss(d) for d in d_s_ri])
    pl_ri_d = np.array([path_loss(d) for d in d_ri_d])  # Path loss from relay to destination
    pl_u_d = path_loss(d_u_d)            

    return d_s_ri, d_u_ri, d_ri_u, d_ri_d, d_u_s, d_u_d, n, pl_s_u, pl_ri_u, pl_u_ri, pl_s_ri, pl_ri_d, pl_u_d

# %%
d_s_ri, d_u_ri, d_ri_u, d_ri_d, d_u_s, d_u_d, n, pl_s_u, pl_ri_u, pl_u_ri, pl_s_ri, pl_ri_d, pl_u_d = generate_map(relay_num=relay_num)

# %%
def detection_prob(P_u, P_x, m_relay, m_source, tau = 1):
    
    P_s = P_x #dBm
    P_s = convert_dBm_W(P_s)
    h_uu = 1e-2
    rho = 1
    tau = 1
                # Distance from UAV to destination

    # Path loss calculations for various distances
    # pl_s_ri = np.array([path_loss(d) for d in d_s_ri])  # Path loss from source to relay
    # pl_ri_d = np.array([path_loss(d) for d in d_ri_d])  # Path loss from relay to destination
    # pl_u_s = path_loss(d_u_s)                           # Path loss from UAV to source
    # pl_u_ri = np.array([path_loss(d) for d in d_u_ri])  # Path loss from UAV to relay
    # pl_u_d = path_loss(d_u_d)                           # Path loss from UAV to destination

    # Power values in dBm
    P_ri = P_x  # Power at relay
    P_ri = convert_dBm_W(P_ri)
    # P_u = 100  # Power at UAV

    # Convert dBm to watts and calculate theta (power over path loss) for various links
    # theta_s_ri = np.array([convert_dBm_W(P_s) / pl for pl in pl_s_ri])  # Source to relay
    # theta_ri_d = np.array([convert_dBm_W(P_ri) / pl for pl in pl_ri_d]) # Relay to destination
    # theta_u_s = convert_dBm_W(P_u) / pl_u_s                             # UAV to source
    theta_s_u = P_s / pl_s_u                             # Source to UAV
    # theta_u_ri = np.array([convert_dBm_W(P_u) / pl for pl in pl_u_ri])  # UAV to relay
    theta_ri_u = np.array([P_ri / pl for pl in pl_ri_u]) # Relay to UAV
    # theta_u_d = convert_dBm_W(P_u) / pl_u_d                             # UAV to destination

    # Calculate beta for various links
    # beta_s_ri = theta_s_ri * P_s / pl_s_ri   # Source to relay
    # beta_ri_d = theta_ri_d * P_ri / pl_ri_d  # Relay to destination
    # beta_u_s = theta_u_s * P_u / pl_u_s      # UAV to source
    beta_s_u = theta_s_u * P_s / pl_s_u      # Source to UAV
    # beta_u_ri = theta_u_ri * P_u / pl_u_ri   # UAV to relay
    beta_ri_u = theta_ri_u * P_ri / pl_ri_u  # Relay to UAV
    # beta_u_d = theta_u_d * P_u / pl_u_d      # UAV to destination

    beta_x_u = beta_ri_u.copy()              # Copy beta values from relay to UAV
    beta_x_u = np.append(beta_x_u, beta_s_u) # Append source to UAV values

    all_transmit_betas = beta_ri_u.copy()
    all_transmit_betas = np.append(all_transmit_betas, beta_s_u)
    beta_min = min(all_transmit_betas)

    coefs_relay = [(beta_min / beta)**m_relay for beta in beta_ri_u]
    coefs_source = (beta_min / beta_s_u)**m_source

    coefs_relay.append(coefs_source)

    coef = np.prod(coefs_relay)

    sigmas = [1]
    for k in range(1, 100):
        epsilons = []
        for j in range(1, k+1):
            epsilon = 0
            epsilon += (m_relay/j) * sum([(1 - beta_min / beta_ri_u[i])**j for i in range(len(beta_ri_u))])
            epsilon += (m_source/j) * ((1 - beta_min / beta_s_u)**j)
            epsilons.append(epsilon)
        sigma = (1/k) * sum([j * epsilons[j-1] * sigmas[k-j] for j in range(1, k+1)])
        sigmas.append(sigma)
    lambda_ = rho * P_u * h_uu

    tau = tau * lambda_
    P_detection_cdf = 1 - (coef * sum([sigmas[k] * gammainc((m_source + m_relay * relay_num) + k, tau/beta_min) for k in range(len(sigmas))]))
    
    return [theta_ri_u, theta_s_u, P_detection_cdf]

# %%
def math_detection_prob(P_x = 40, P_u_start = 34, P_u_end = 45, m_relay = 2, m_source = 2):
    P_u_range = convert_dBm_W(np.array([i/10 for i in range(P_u_start*10, P_u_end*10 + 1, 1)]))
    P_detection = [detection_prob(i, P_x, m_relay, m_source)[-1] for i in P_u_range]
    return P_detection

def sim_detection_prob(P_x = 40, P_u_start = 20, P_u_end = 50, m_relay = 2, m_source = 2, num_samples = 10**7):
    P_s = P_x #dBm
    P_s = convert_dBm_W(P_s)

    P_ri = P_x  # Power at relay
    P_ri = convert_dBm_W(P_ri)
 
    theta_s_u = P_s / pl_s_u                             # Source to UAV
    theta_ri_u = np.array([P_ri / pl for pl in pl_ri_u]) # Relay to UAV

    print('Generating Gamma random variables.')

    h_ri_u = np.array([np.random.gamma(m_relay, theta_ri_u[i], num_samples) for i in range(n-1)])
    h_s_u = np.array(np.random.gamma(m_source, theta_s_u, num_samples))
    P_detection_mc = []

    numerator = 0

    numerator += P_s * h_s_u / pl_s_u
    numerator += sum(P_ri * h_ri_u / pl_ri_u.reshape(-1,1))

    P_u_range = convert_dBm_W(np.array([i/100 for i in range(P_u_start*100, P_u_end*100 + 1, 1)]))

    print('Calculating values.')

    for P_u in P_u_range:
        temp = numerator / (rho * P_u * h_uu) 
        print(numerator)
        P_detection_mc.append(np.mean(temp > tau))
    return P_detection_mc

def calculate_prob_det(P_x = 40, P_u_start = 20, P_u_end = 50, m_relay = 2, m_source = 2):
    print('Calculating detection probability using mathematical method.')
    P_detection = math_detection_prob(P_x, P_u_start, P_u_end, m_relay, m_source)

    print('Calculating detection probability using simulation method.')
    P_detection_mc = sim_detection_prob(P_x, P_u_start, P_u_end, m_relay, m_source, num_samples = 10**7)
    print('Done \n')
    return P_detection, P_detection_mc

# %% [markdown]
# \begin{align*}
# &S = \sum_{x\in\mathcal{X}_{\text{active}}} \Gamma(m, \beta_i) \\
# &\Rightarrow F_s(x)= C\sum_{k=0}^{\infty }\sigma_k\frac{\gamma(Nm+k,\frac{x}{\beta_{min}})}{\Gamma(Nm+k)}\frac{1}{\lambda}
# \end{align*}

# %% [markdown]
# \begin{align*}
# & \beta_i = \frac{P_x\theta_i}{\mathrm{PL}_{x\to U}(d_{x,U})} \\
# & \beta_{min} = min(\beta_i)\\
# & C = \prod_{i=1}^{N}(\frac{\beta_{min}}{\beta_i})^m \\
# & \sigma_0 = 1, \sigma_k= \frac{1}{k}\sum_{j=1}^{k}j\varepsilon_j\sigma_{k-j}, \varepsilon_j=\sum_{i=1}^{N}\frac{m}{j}(1-\frac{\beta_{min}}{\beta_i})^j \\
# & \lambda = N_0 + I^{(\mathrm{ext})}
#       + \rho\,P_U^{} |h_{U,U}|^2
# \end{align*}

# %%
P_u_start = 25
P_u_end = 45
P_x_start = 25
P_x_end = 45

# %%
P_detection_3d = []
for P_x in range(P_x_start*10, P_x_end*10 + 1):
    P_x = P_x / 10
    print(f'P_x = {P_x} \n')
    
    P_detection = math_detection_prob(P_x, P_u_start, P_u_end, 2, 2)
    P_detection_3d.append(P_detection)
    with open(f'checkpoint_det_{relay_num}_relay_(with_h).pkl', 'wb') as f:
        pickle.dump(P_detection_3d, f)
# Out:
# P_x = 25.0
#
# P_x = 25.1
#
# P_x = 25.2
#
# P_x = 25.3
#
# P_x = 25.4
#
# P_x = 25.5
#
# P_x = 25.6
#
# P_x = 25.7
#
# P_x = 25.8
#
# P_x = 25.9
#
# P_x = 26.0
#
# P_x = 26.1
#
# P_x = 26.2
#
# P_x = 26.3
#
# P_x = 26.4
#
# P_x = 26.5
#
# P_x = 26.6
#
# P_x = 26.7
#
# P_x = 26.8
#
# P_x = 26.9
#
# P_x = 27.0
#
# P_x = 27.1
#
# P_x = 27.2
#
# P_x = 27.3
#
# P_x = 27.4
#
# P_x = 27.5
#
# P_x = 27.6
#
# P_x = 27.7
#
# P_x = 27.8
#
# P_x = 27.9
#
# P_x = 28.0
#
# P_x = 28.1
#
# P_x = 28.2
#
# P_x = 28.3
#
# P_x = 28.4
#
# P_x = 28.5
#
# P_x = 28.6
#
# P_x = 28.7
#
# P_x = 28.8
#
# P_x = 28.9
#
# P_x = 29.0
#
# P_x = 29.1
#
# P_x = 29.2
#
# P_x = 29.3
#
# P_x = 29.4
#
# P_x = 29.5
#
# P_x = 29.6
#
# P_x = 29.7
#
# P_x = 29.8
#
# P_x = 29.9
#
# P_x = 30.0
#
# P_x = 30.1
#
# P_x = 30.2
#
# P_x = 30.3
#
# P_x = 30.4
#
# P_x = 30.5
#
# P_x = 30.6
#
# P_x = 30.7
#
# P_x = 30.8
#
# P_x = 30.9
#
# P_x = 31.0
#
# P_x = 31.1
#
# P_x = 31.2
#
# P_x = 31.3
#
# P_x = 31.4
#
# P_x = 31.5
#
# P_x = 31.6
#
# P_x = 31.7
#
# P_x = 31.8
#
# P_x = 31.9
#
# P_x = 32.0
#
# P_x = 32.1
#
# P_x = 32.2
#
# P_x = 32.3
#
# P_x = 32.4
#
# P_x = 32.5
#
# P_x = 32.6
#
# P_x = 32.7
#
# P_x = 32.8
#
# P_x = 32.9
#
# P_x = 33.0
#
# P_x = 33.1
#
# P_x = 33.2
#
# P_x = 33.3
#
# P_x = 33.4
#
# P_x = 33.5
#
# P_x = 33.6
#
# P_x = 33.7
#
# P_x = 33.8
#
# P_x = 33.9
#
# P_x = 34.0
#
# P_x = 34.1
#
# P_x = 34.2
#
# P_x = 34.3
#
# P_x = 34.4
#
# P_x = 34.5
#
# P_x = 34.6
#
# P_x = 34.7
#
# P_x = 34.8
#
# P_x = 34.9
#
# P_x = 35.0
#
# P_x = 35.1
#
# P_x = 35.2
#
# P_x = 35.3
#
# P_x = 35.4
#
# P_x = 35.5
#
# P_x = 35.6
#
# P_x = 35.7
#
# P_x = 35.8
#
# P_x = 35.9
#
# P_x = 36.0
#
# P_x = 36.1
#
# P_x = 36.2
#
# P_x = 36.3
#
# P_x = 36.4
#
# P_x = 36.5
#
# P_x = 36.6
#
# P_x = 36.7
#
# P_x = 36.8
#
# P_x = 36.9
#
# P_x = 37.0
#
# P_x = 37.1
#
# P_x = 37.2
#
# P_x = 37.3
#
# P_x = 37.4
#
# P_x = 37.5
#
# P_x = 37.6
#
# P_x = 37.7
#
# P_x = 37.8
#
# P_x = 37.9
#
# P_x = 38.0
#
# P_x = 38.1
#
# P_x = 38.2
#
# P_x = 38.3
#
# P_x = 38.4
#
# P_x = 38.5
#
# P_x = 38.6
#
# P_x = 38.7
#
# P_x = 38.8
#
# P_x = 38.9
#
# P_x = 39.0
#
# P_x = 39.1
#
# P_x = 39.2
#
# P_x = 39.3
#
# P_x = 39.4
#
# P_x = 39.5
#
# P_x = 39.6
#
# P_x = 39.7
#
# P_x = 39.8
#
# P_x = 39.9
#
# P_x = 40.0
#
# P_x = 40.1
#
# P_x = 40.2
#
# P_x = 40.3
#
# P_x = 40.4
#
# P_x = 40.5
#
# P_x = 40.6
#
# P_x = 40.7
#
# P_x = 40.8
#
# P_x = 40.9
#
# P_x = 41.0
#
# P_x = 41.1
#
# P_x = 41.2
#
# P_x = 41.3
#
# P_x = 41.4
#
# P_x = 41.5
#
# P_x = 41.6
#
# P_x = 41.7
#
# P_x = 41.8
#
# P_x = 41.9
#
# P_x = 42.0
#
# P_x = 42.1
#
# P_x = 42.2
#
# P_x = 42.3
#
# P_x = 42.4
#
# P_x = 42.5
#
# P_x = 42.6
#
# P_x = 42.7
#
# P_x = 42.8
#
# P_x = 42.9
#
# P_x = 43.0
#
# P_x = 43.1
#
# P_x = 43.2
#
# P_x = 43.3
#
# P_x = 43.4
#
# P_x = 43.5
#
# P_x = 43.6
#
# P_x = 43.7
#
# P_x = 43.8
#
# P_x = 43.9
#
# P_x = 44.0
#
# P_x = 44.1
#
# P_x = 44.2
#
# P_x = 44.3
#
# P_x = 44.4
#
# P_x = 44.5
#
# P_x = 44.6
#
# P_x = 44.7
#
# P_x = 44.8
#
# P_x = 44.9
#
# P_x = 45.0

# %%
# Phase 1 Outage Probability
def phase1_outage_prob(P_s, P_u, m_relay = 2, m_source = 2, num_samples = 10000):
    P_s = convert_dBm_W(P_s)
    P_u = convert_dBm_W(P_u)
    
    theta_s_ri = np.array([P_s / pl for pl in pl_s_ri])    # Source to relay
    theta_u_ri = np.array([P_u / pl for pl in pl_u_ri])    # UAV to relay

    print('Generating Gamma random variables.')

    h_s_ri = np.array([np.random.gamma(m_relay, theta_s_ri[i], num_samples) for i in range(relay_num)])
    h_u_ri = np.array([np.random.gamma(m_relay, theta_u_ri[i], num_samples) for i in range(relay_num)])
    
    SINRs = []
    for ri in range(relay_num):
        SINR = (P_s * h_s_ri[ri] / pl_s_ri[ri]) / (noise + P_u * h_u_ri[ri] / pl_u_ri[ri]) 
        SINRs.append(SINR)
    SINRs = np.array(SINRs)

    return np.array([np.mean(i < tau) for i in SINRs])

# %%
# Phase 2 Outage Probability
def phase2_outage_prob(P_ri, P_u, m_relay = 2, m_source = 2, num_samples = 10000):
    P_ri = convert_dBm_W(P_ri)
    P_u = convert_dBm_W(P_u)
 
    theta_ri_d = np.array([P_ri / pl for pl in pl_ri_d])   # Source to relay
    theta_u_d = P_u / pl_u_d     # UAV to relay

    print('Generating Gamma random variables.')

    h_ri_d = np.array([np.random.gamma(m_relay, theta_ri_d[i], num_samples) for i in range(relay_num)])
    h_u_d = np.random.gamma(m_relay, theta_u_d, num_samples)
    
    SINRs = []
    for ri in range(relay_num):
        SINR = (P_ri * h_ri_d[ri] / pl_ri_d[ri]) / (noise + P_u * h_u_d / pl_u_d) 
        SINRs.append(SINR)
    SINRs = np.array(SINRs)

    return np.array([np.mean(i < tau) for i in SINRs])

# %%
def e2e_succ_prob(P_s, P_ri, P_u, m_relay = 2, m_source = 2, num_samples = 10000):
    phase1_succ_i = 1 - phase1_outage_prob(P_s, P_u, m_relay, m_source, num_samples)
    phase2_succ_i = 1 - phase2_outage_prob(P_ri, P_u, m_relay, m_source, num_samples)

    both_phase_succ_i = phase1_succ_i * phase2_succ_i

    e2e_succ = 1 - np.prod(1 - both_phase_succ_i)

    return e2e_succ

# %%
def e2e_succ_prob_3d(P_u_start = 25, P_u_end = 45, P_x_start = 25, P_x_end = 45):
    P_succ_3d = []
    for P_x in range(P_x_start*10, P_x_end*10+1):
        temp = []
        P_x = P_x / 10
        for P_u in range(P_u_start*10, P_u_end*10+1):
            P_u = P_u / 10
            print(f'P_x = {P_x}, P_u = {P_u} \n')
            
            succ_proc = e2e_succ_prob(P_x, P_x, P_u)
            temp.append(succ_proc)
        P_succ_3d.append(temp)
        with open(f'checkpoint_succ_{relay_num}_relay_(with_h).pkl', 'wb') as f:
            pickle.dump(P_succ_3d, f)
    return P_succ_3d

# %%
P_succ_3d = e2e_succ_prob_3d(P_u_start, P_u_end, P_x_start, P_x_end)
# Out:
# P_x = 25.0, P_u = 25.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 25.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 26.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 27.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 28.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 29.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 30.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 31.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 32.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 33.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 34.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 35.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 36.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 37.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 38.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 39.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 40.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 41.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 42.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 43.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 44.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.0, P_u = 45.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 25.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 26.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 27.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 28.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 29.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 30.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 31.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 32.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 33.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 34.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 35.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 36.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 37.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 38.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 39.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 40.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 41.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 42.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 43.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 44.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.1, P_u = 45.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 25.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 26.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 27.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 28.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 29.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 30.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 31.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 32.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 33.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 34.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 35.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 35.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 35.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 25.2, P_u = 35.3
#
# ...
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 35.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 35.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 35.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 35.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 35.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 35.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 36.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 37.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 38.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 39.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 40.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 41.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 42.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 43.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 44.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 30.9, P_u = 45.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 25.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 26.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 27.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 28.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.2
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.3
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.4
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.5
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.6
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.7
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.8
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 29.9
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 30.0
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# P_x = 31.0, P_u = 30.1
#
# Generating Gamma random variables.
# Generating Gamma random variables.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 P_succ_3d = e2e_succ_prob_3d(P_u_start, P_u_end, P_x_start, P_x_end)
#
# Cell In[14], line 10, in e2e_succ_prob_3d(P_u_start, P_u_end, P_x_start, P_x_end)
#       7     P_u = P_u / 10
#       8     print(f'P_x = {P_x}, P_u = {P_u} \n')
# ---> 10     succ_proc = e2e_succ_prob(P_x, P_x, P_u)
#      11     temp.append(succ_proc)
#      12 P_succ_3d.append(temp)
#
# Cell In[13], line 3, in e2e_succ_prob(P_s, P_ri, P_u, m_relay, m_source, num_samples)
#       1 def e2e_succ_prob(P_s, P_ri, P_u, m_relay = 2, m_source = 2, num_samples = 10000):
#       2     phase1_succ_i = 1 - phase1_outage_prob(P_s, P_u, m_relay, m_source, num_samples)
# ----> 3     phase2_succ_i = 1 - phase2_outage_prob(P_ri, P_u, m_relay, m_source, num_samples)
#       5     both_phase_succ_i = phase1_succ_i * phase2_succ_i
#       7     e2e_succ = 1 - np.prod(1 - both_phase_succ_i)
#
# Cell In[12], line 11, in phase2_outage_prob(P_ri, P_u, m_relay, m_source, num_samples)
#       7 theta_u_d = P_u / pl_u_d     # UAV to relay
#       9 print('Generating Gamma random variables.')
# ---> 11 h_ri_d = np.array([np.random.gamma(m_relay, theta_ri_d[i], num_samples) for i in range(relay_num)])
#      12 h_u_d = np.random.gamma(m_relay, theta_u_d, num_samples)
#      14 SINRs = []
#
# Cell In[12], line 11, in <listcomp>(.0)
#       7 theta_u_d = P_u / pl_u_d     # UAV to relay
#       9 print('Generating Gamma random variables.')
# ---> 11 h_ri_d = np.array([np.random.gamma(m_relay, theta_ri_d[i], num_samples) for i in range(relay_num)])
#      12 h_u_d = np.random.gamma(m_relay, theta_u_d, num_samples)
#      14 SINRs = []
#
# KeyboardInterrupt:

# %%
# import numpy as np
# import plotly.graph_objects as go

# with open(f'checkpoint_succ_{relay_num}_relay.pkl', 'rb') as f:
#     P_succ_3d = pickle.load(f)

# P_outage_3d = 1 - np.array(P_succ_3d)

# with open(f'checkpoint_det_{relay_num}_relay.pkl', 'rb') as f:
#     P_det_3d = pickle.load(f)

# P_x_range = np.array(range(P_x_start*10, P_x_end*10+1)) / 10
# P_u_range = np.array(range(P_u_start*10, P_u_end*10+1)) / 10

# # Create meshgrid
# X, Y = np.meshgrid(P_u_range, P_x_range)
# Z_out = np.array(P_outage_3d)
# Z_det = np.array(P_det_3d)
# Z_flat = np.full_like(Z_out, 0.1)


# fig = go.Figure()

# # Add success surface
# fig.add_trace(go.Surface(
#     name= 'Outage Probability',
#     z=Z_out,
#     x=X,
#     y=Y,
#     colorscale='viridis',
#     opacity=1,
#     showscale=False,
#     showlegend= True
# ))

# fig.add_trace(go.Surface(
#     name= 'Detection Probability',
#     z=Z_det,
#     x=X,
#     y=Y,
#     colorscale='inferno',
#     opacity=1,
#     showscale=False,
#     showlegend= True
# ))

# # Add flat reference plane
# fig.add_trace(go.Surface(
#     name= 'Acceptable Outage / Detection',
#     z=Z_flat,
#     x=X,
#     y=Y,
#     surfacecolor=np.ones_like(Z_flat),  # dummy color to force rendering
#     colorscale=[[0, 'red'], [1, 'red']],
#     showscale=False,
#     opacity=0.7,
#     showlegend= True
# ))

# # Create a combined mask array:
# # 0 = no violation, 1 = too high, 2 = too low
# violation_map = np.zeros_like(Z_flat)
# violation_map[(Z_flat > Z_out) & (Z_flat > Z_det)] = 1  # too high
# violation_map[(Z_flat < Z_out) & (Z_flat < Z_det)] = 2  # too low

# # Only display values where violation occurs
# highlight_combined = np.where(violation_map > 0, Z_flat, np.nan)

# # Add single combined surface
# fig.add_trace(go.Surface(
#     name='Violation Regions',
#     z=highlight_combined,
#     x=X,
#     y=Y,
#     surfacecolor=violation_map,
#     colorscale=[
#     [0.0, 'rgba(0,0,0,0)'],
#     [0.5, '#FF00FF'],  # magenta
#     [1.0, '#00FF00']   # lime green
#     ],
#     cmin=0,
#     cmax=2,
#     showscale=False,
#     opacity=0.5,
#     showlegend=True
# ))
# # Labels

# fig.update_layout(
#     scene=dict(
#         xaxis=dict(
#             title='<b> UAV Jamming Power (dBm)</b>' ,

#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',  # soft blue-gray
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         yaxis=dict(
#             title='<b> Source & Relay Transmit Power (dBm)</b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         zaxis=dict(
#             title='<b> Probability </b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         )
#     ),
#     width=800,
#     height=800,
#     margin=dict(l=0, r=0, t=0, b=0)
# )

# fig.show()

# %%
# import numpy as np
# import plotly.graph_objects as go

# with open(f'checkpoint_succ_{relay_num}_relay.pkl', 'rb') as f:
#     P_succ_3d = pickle.load(f)

# P_outage_3d = 1 - np.array(P_succ_3d)

# with open(f'checkpoint_det_{relay_num}_relay.pkl', 'rb') as f:
#     P_det_3d = pickle.load(f)

# P_x_range = np.array(range(P_x_start*10, P_x_end*10+1)) / 10
# P_u_range = np.array(range(P_u_start*10, P_u_end*10+1)) / 10

# # Create meshgrid
# X, Y = np.meshgrid(P_u_range, P_x_range)
# Z_out = np.array(P_outage_3d)
# Z_det = np.array(P_det_3d)
# Z_flat = np.full_like(Z_out, 0.1)


# fig = go.Figure()

# # Add success surface
# fig.add_trace(go.Surface(
#     name= 'Outage Probability',
#     z=Z_out,
#     x=X,
#     y=Y,
#     colorscale='Viridis',
#     opacity=1,
#     showscale=False,
#     showlegend= True
# ))

# fig.add_trace(go.Surface(
#     name= 'Detection Probability',
#     z=Z_det,
#     x=X,
#     y=Y,
#     colorscale='Plasma',
#     opacity=1,
#     showscale=False,
#     showlegend= True
# ))

# # # Add flat reference plane
# # fig.add_trace(go.Surface(
# #     name= 'Acceptable level of Outage / Detection',
# #     z=Z_flat,
# #     x=X,
# #     y=Y,
# #     surfacecolor=np.ones_like(Z_flat),  # dummy color to force rendering
# #     colorscale=[[0, 'red'], [1, 'red']],
# #     showscale=False,
# #     opacity=0.7,
# #     showlegend= True
# # ))

# # Create a combined mask array:
# # 0 = no violation, 1 = too high, 2 = too low
# violation_map = np.zeros_like(Z_flat)
# violation_map[(Z_flat > Z_out) & (Z_flat > Z_det)] = 1  # too high
# violation_map[(Z_flat < Z_out) & (Z_flat < Z_det)] = 2  # too low

# # Only display values where violation occurs
# highlight_combined = np.where(violation_map > 0, Z_flat, np.nan)

# # Add single combined surface
# fig.add_trace(go.Surface(
#     name='Acceptable Region',
#     z=highlight_combined,
#     x=X,
#     y=Y,
#     surfacecolor=violation_map,
#     colorscale=[
#     [0.0, 'rgba(0,0,0,0)'],
#     [0.5, '#00FF00'],  # lime green
#     [1.0, '#00FF00']   # lime green
#     ],
#     cmin=0,
#     cmax=2,
#     showscale=False,
#     opacity=0.8,
#     showlegend=True
# ))
# # Labels

# fig.update_layout(
#     scene=dict(
#         camera=dict(
#             eye=dict(x=1.5, y=0.9375, z=2.34375)),
#         xaxis=dict(
#             title='<b> UAV Jamming Power (dBm)</b>' ,

#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',  # soft blue-gray
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         yaxis=dict(
#             title='<b> Source & Relay Transmit Power (dBm)</b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         zaxis=dict(
#             title='<b> Probability </b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         )
#     ),
#     width=800,
#     height=800,
#     margin=dict(l=0, r=0, t=0, b=0)
# )
# fig.update_layout(
#     legend=dict(
#         x=0.98,  # near left
#         y=0.98,  # near top
#         xanchor='right',
#         yanchor='top',
#         font=dict(size=45),
#         bgcolor='rgba(255,255,255,0.6)',  # semi-transparent
#         bordercolor='gray',
#         borderwidth=1
#     ),
#     margin=dict(l=0, r=0, t=0, b=0)  # no extra space for legend
# )
# fig.show()

# %%
# fig.write_image("Acceptable Region.png", width=2000, height=2000, scale=4)

# %%
# mask_high = (Z_flat > Z_out) & (Z_flat > Z_det)  # too high
# mask_low = (Z_flat < Z_out) & (Z_flat < Z_det)   # too low

# # Combine both conditions (for both too high and too low)
# highlight_mask = mask_high | mask_low

# # Calculate the total area
# # Get the spacing between each grid point (assuming uniform grid)
# dx = P_u_range[1] - P_u_range[0]
# dy = P_x_range[1] - P_x_range[0]

# # Calculate the number of highlighted grid points
# highlighted_points = np.sum(highlight_mask)

# # Area is the number of highlighted points times the area of each grid cell
# highlighted_area = highlighted_points * dx * dy
# print(f"Highlighted area: {highlighted_area} square units")

# mask_temp = (np.abs(Z_flat - Z_det) < 1e-2) & (np.abs(Z_flat - Z_out) < 1e-2)

# %% [markdown]
# - Impact of UAV jamming power: As UAV jamming power increases, the acceptable range of our transmit power gradually narrows. Eventually, if UAV jamming power gets high enough, we are able to increase our transmit power more freely. Regardless of UAV jamming power, there is always a sweet spot that allows us to send messages with a low chance of outage and detection. This sweet spot depends on UAV jamming power. <br/>
# $\textbf{However, we cannot control UAV jamming power. At best, we can assume a fixed value for it.}$
# <br/><br/>
# - Impact of relay num:

# %%
# import numpy as np
# import plotly.graph_objects as go

# with open(f'checkpoint_succ_5_relay.pkl', 'rb') as f:
#     P_succ_3d_5 = pickle.load(f)
# P_outage_3d_5 = 1 - np.array(P_succ_3d_5)

# with open(f'checkpoint_succ_10_relay.pkl', 'rb') as f:
#     P_succ_3d_10 = pickle.load(f)
# P_outage_3d_10 = 1 - np.array(P_succ_3d_10)

# with open(f'checkpoint_succ_20_relay.pkl', 'rb') as f:
#     P_succ_3d_20 = pickle.load(f)
# P_outage_3d_20 = 1 - np.array(P_succ_3d_20)

# with open(f'checkpoint_succ_30_relay.pkl', 'rb') as f:
#     P_succ_3d_30 = pickle.load(f)
# P_outage_3d_30 = 1 - np.array(P_succ_3d_30)

# P_x_range = np.array(range(P_x_start*10, P_x_end*10+1)) / 10
# P_u_range = np.array(range(P_u_start*10, P_u_end*10+1)) / 10

# # Create meshgrid
# X, Y = np.meshgrid(P_u_range, P_x_range)
# Z_out_5 = np.array(P_outage_3d_5)
# Z_out_10 = np.array(P_outage_3d_10)
# Z_out_20 = np.array(P_outage_3d_20)
# Z_out_30 = np.array(P_outage_3d_30)
# Z_flat = np.full_like(Z_out_5, 0.1)

# fig = go.Figure()

# fig.add_trace(go.Surface(
#     name='Outage Probability - 30 relays',
#     z=Z_out_30,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'green'], [1, 'green']],
#     opacity=0.3,
#     showscale=False,
#     showlegend=True
# ))

# fig.add_trace(go.Surface(
#     name='Outage Probability - 20 relays',
#     z=Z_out_20,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'blue'], [1, 'blue']],
#     opacity=0.5,
#     showscale=False,
#     showlegend=True
# ))

# fig.add_trace(go.Surface(
#     name='Outage Probability - 10 relays',
#     z=Z_out_10,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'orange'], [1, 'orange']],
#     opacity=0.7,
#     showscale=False,
#     showlegend=True
# ))

# fig.add_trace(go.Surface(
#     name='Outage Probability - 5 relays',
#     z=Z_out_5,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'red'], [1, 'red']],
#     opacity=0.9,
#     showscale=False,
#     showlegend=True
# ))

# fig.update_layout(
#     scene=dict(
#         camera=dict(
#             eye=dict(x=-1.5, y=-1.5, z=1.5)),
#         xaxis=dict(
#             title='<b> UAV Jamming Power (dBm)</b>' ,

#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',  # soft blue-gray
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         yaxis=dict(
#             title='<b> Source & Relay Transmit Power (dBm)</b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         zaxis=dict(
#             title='<b> Outage Probability </b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         )
#     ),
#     width=1000,
#     height=1000,
#     margin=dict(l=0, r=0, t=0, b=0)
# )

# fig.update_layout(
#     legend=dict(
#         x=0.98,  # near left
#         y=0.98,  # near top
#         xanchor='right',
#         yanchor='top',
#         font=dict(size=45),
#         bgcolor='rgba(255,255,255,0.6)',  # semi-transparent
#         bordercolor='gray',
#         borderwidth=1
#     ),
#     margin=dict(l=0, r=0, t=0, b=0)  # no extra space for legend
# )

# fig.show()

# %%
# fig.write_image("Outage Probability - Multi-relay low res.png", width=2000, height=2000, scale=0.5)

# %%
# P_u_range[100]

# %% [markdown]
# The fewer relay we have, the higher our transmit power has to be to have the desired outage probability.

# %%
# import numpy as np
# import plotly.graph_objects as go

# with open(f'checkpoint_det_5_relay.pkl', 'rb') as f:
#     P_det_3d_5 = pickle.load(f)

# with open(f'checkpoint_det_10_relay.pkl', 'rb') as f:
#     P_det_3d_10 = pickle.load(f)

# with open(f'checkpoint_det_20_relay.pkl', 'rb') as f:
#     P_det_3d_20 = pickle.load(f)

# with open(f'checkpoint_det_30_relay.pkl', 'rb') as f:
#     P_det_3d_30 = pickle.load(f)

# P_x_range = np.array(range(P_x_start*10, P_x_end*10+1)) / 10
# P_u_range = np.array(range(P_u_start*10, P_u_end*10+1)) / 10

# # Create meshgrid
# X, Y = np.meshgrid(P_u_range, P_x_range)
# Z_det_5 = np.array(P_det_3d_5)
# Z_det_10 = np.array(P_det_3d_10)
# Z_det_20 = np.array(P_det_3d_20)
# Z_det_30 = np.array(P_det_3d_30)
# Z_flat = np.full_like(Z_det_5, 0.1)

# # Add success surface
# fig = go.Figure()

# fig.add_trace(go.Surface(
#     name='Detection Probability - 5 relays',
#     z=Z_det_5,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'green'], [1, 'green']],
#     opacity=0.3,
#     showscale=False,
#     showlegend=True
# ))

# fig.add_trace(go.Surface(
#     name='Detection Probability - 10 relays',
#     z=Z_det_10,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'blue'], [1, 'blue']],
#     opacity=0.5,
#     showscale=False,
#     showlegend=True
# ))

# fig.add_trace(go.Surface(
#     name='Detection Probability - 20 relays',
#     z=Z_det_20,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'orange'], [1, 'orange']],
#     opacity=0.7,
#     showscale=False,
#     showlegend=True
# ))

# fig.add_trace(go.Surface(
#     name='Detection Probability - 30 relays',
#     z=Z_det_30,
#     x=X,
#     y=Y,
#     colorscale=[[0, 'red'], [1, 'red']],
#     opacity=0.9,
#     showscale=False,
#     showlegend=True
# ))


# fig.update_layout(
#     scene=dict(
#         camera=dict(
#             eye=dict(x=-1.5, y=-1.5, z=1.5)),
#         xaxis=dict(
#             title='<b> UAV Jamming Power (dBm)</b>' ,

#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',  # soft blue-gray
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         yaxis=dict(
#             title='<b> Source & Relay Transmit Power (dBm)</b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         ),
#         zaxis=dict(
#             title='<b> Detection Probability </b>',
#             showbackground=True,
#             backgroundcolor='rgb(230, 235, 245)',
#             showgrid=True,
#             gridcolor='black',
#             zerolinecolor='black',
#             linecolor='black'
#         )
#     ),
#     width=1000,
#     height=1000,
#     margin=dict(l=0, r=0, t=0, b=0)
# )
# fig.update_layout(
#     legend=dict(
#         x=0.98,  # near left
#         y=0.98,  # near top
#         xanchor='right',
#         yanchor='top',
#         font=dict(size=45),
#         bgcolor='rgba(255,255,255,0.6)',  # semi-transparent
#         bordercolor='gray',
#         borderwidth=1
#     ),
#     margin=dict(l=0, r=0, t=0, b=0)  # no extra space for legend
# )

# fig.show()

# %%
# fig.write_image("Detection Probability - Multi-relay low res.png", width=2000, height=2000, scale=0.5)

# %%
# P_succ_2d_5 = np.array(P_succ_3d_5)[:, 100]

# P_succ_2d_10 = np.array(P_succ_3d_10)[:, 100]

# P_succ_2d_20 = np.array(P_succ_3d_20)[:, 100]

# P_succ_2d_30 = np.array(P_succ_3d_30)[:, 100]

# plt.figure(figsize=(10, 6))
# plt.plot(P_x_range, P_succ_2d_5, label="Outage Probability - 5 relays")
# plt.plot(P_x_range, P_succ_2d_10, label="Outage Probability - 10 relays")
# plt.plot(P_x_range, P_succ_2d_20, label="Outage Probability - 20 relays")
# plt.plot(P_x_range, P_succ_2d_30, label="Outage Probability - 30 relays")
# plt.axhline(y=0.1, color='r', linestyle='--', label="Acceptable Outage = 0.1")
# plt.xlabel('Transmit Power (dBm)', fontsize=14)
# plt.ylabel('Outage Probability', fontsize=14)
# plt.grid(True)
# plt.legend(fontsize=14)
# plt.tight_layout()
# plt.show()

# %%
# P_det_2d_5 = np.array(P_det_3d_5)[:, 100]

# P_det_2d_10 = np.array(P_det_3d_10)[:, 100]

# P_det_2d_20 = np.array(P_det_3d_20)[:, 100]

# P_det_2d_30 = np.array(P_det_3d_30)[:, 100]

# plt.figure(figsize=(10, 6))
# plt.plot(P_x_range, P_det_2d_5, label="Detection Probability - 5 relays")
# plt.plot(P_x_range, P_det_2d_10, label="Detection Probability - 10 relays")
# plt.plot(P_x_range, P_det_2d_20, label="Detection Probability - 20 relays")
# plt.plot(P_x_range, P_det_2d_30, label="Detection Probability - 30 relays")
# plt.axhline(y=0.1, color='r', linestyle='--', label="Acceptable Detection = 0.1")
# plt.xlabel('Transmit Power (dBm)', fontsize=14)
# plt.ylabel('Detection Probability', fontsize=14)
# plt.grid(True)
# plt.legend(fontsize=14)
# plt.tight_layout()
# plt.show()

# %%
# P_outage_2d_5 = 1 - np.array(P_succ_2d_5)
# P_det_2d_5 = np.array(P_det_2d_5)
# P_outage_2d_30 = 1 - np.array(P_succ_2d_30)
# P_det_2d_30 = np.array(P_det_2d_30)
# mask = (P_outage_2d_5 < 0.1) & (P_det_2d_5 < 0.1)

# %%
# plt.figure(figsize=(10, 6))
# mask = (P_outage_2d_5 < 0.1) & (P_det_2d_5 < 0.1)

# # Plot base lines
# # plt.figure(figsize=(10, 6))
# plt.plot(P_x_range, P_outage_2d_5, label="Outage Probability - 5 relays")
# plt.plot(P_x_range, P_det_2d_5, label="Detection Probability - 5 relays")
# # plt.axhline(y=0.1, color='r', linestyle='--', label="Acceptable Detection = 0.1")

# cutoff_indices = np.where(mask)[0]

# if cutoff_indices.size > 0:
#     start_idx = cutoff_indices[0]
#     end_idx = cutoff_indices[-1]
#     start_cutoff = P_x_range[start_idx]
#     end_cutoff = P_x_range[end_idx]

#     # plt.axvline(x=start_cutoff, color='black', linestyle='--', label=f'x = {start_cutoff}')
#     # plt.axvline(x=end_cutoff, color='black', linestyle=':', label=f'x = {end_cutoff}')

# plt.fill_between([start_cutoff, end_cutoff], 
#                  0, 
#                  0.1, 
#                  color='green', 
#                  alpha=0.6, 
#                  label='Acceptable Area - 5 relays')

# mask = (P_outage_2d_30 < 0.1) & (P_det_2d_30 < 0.1)

# # Plot base lines
# plt.plot(P_x_range, P_outage_2d_30, label="Outage Probability - 30 relays")
# plt.plot(P_x_range, P_det_2d_30, label="Detection Probability - 30 relays")

# cutoff_indices = np.where(mask)[0]

# if cutoff_indices.size > 0:
#     start_idx = cutoff_indices[0]
#     end_idx = cutoff_indices[-1]
#     start_cutoff = P_x_range[start_idx]
#     end_cutoff = P_x_range[end_idx]

#     # plt.axvline(x=start_cutoff, color='black', linestyle='--', label=f'x = {start_cutoff}')
#     # plt.axvline(x=end_cutoff, color='black', linestyle=':', label=f'x = {end_cutoff}')

# plt.fill_between([start_cutoff, end_cutoff], 
#                  0, 
#                  0.1, 
#                  color='red', 
#                  alpha=0.6, 
#                  label='Acceptable Area - 30 relays')

# plt.axhline(y=0.1, color='r', linestyle='--', label="Acceptable Detection = 0.1")

# plt.xlabel('Transmit Power (dBm)')
# plt.ylabel('Outage / Detection Probability')
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# P_x_range[start_idx:end_idx]

# %% [markdown]
# The more relays we have, the likelier it is that we get detected. The effect of increasing the number of relays seems to be much more noticeable with detection probability.

# %% [markdown]
# This means that as we increase the number of relay, the range of transmit power where we can safely send signals decrease, as seen below.

# %%
# def calculate_intersection(relay_num):
#     with open(f'checkpoint_succ_{relay_num}_relay.pkl', 'rb') as f:
#         P_succ_3d = pickle.load(f)

#     P_outage_3d = 1 - np.array(P_succ_3d)

#     with open(f'checkpoint_det_{relay_num}_relay.pkl', 'rb') as f:
#         P_det_3d = pickle.load(f)

#     P_x_range = np.array(range(P_x_start*10, P_x_end*10+1)) / 10
#     P_u_range = np.array(range(P_u_start*10, P_u_end*10+1)) / 10

#     # Create meshgrid
#     X, Y = np.meshgrid(P_u_range, P_x_range)
#     Z_out = np.array(P_outage_3d)
#     Z_det = np.array(P_det_3d)
#     Z_flat = np.full_like(Z_out, 0.1)

#     mask_high = (Z_flat > Z_out) & (Z_flat > Z_det)  # too high
#     mask_low = (Z_flat < Z_out) & (Z_flat < Z_det)   # too low

#     # Combine both conditions (for both too high and too low)
#     highlight_mask = mask_high | mask_low

#     # Calculate the total area
#     # Get the spacing between each grid point (assuming uniform grid)
#     dx = P_u_range[1] - P_u_range[0]
#     dy = P_x_range[1] - P_x_range[0]

#     # Calculate the number of highlighted grid points
#     highlighted_points = np.sum(highlight_mask)

#     # Area is the number of highlighted points times the area of each grid cell
#     highlighted_area = highlighted_points * dx * dy
#     print(f"Number of relays: {relay_num} \n Highlighted area: {highlighted_area} square units \n")

#     return highlighted_area

# %%
# def calculate_intersection_ranges(relay_num):
#     import pickle
#     import numpy as np

#     with open(f'checkpoint_succ_{relay_num}_relay.pkl', 'rb') as f:
#         P_succ_3d = pickle.load(f)

#     P_outage_3d = 1 - np.array(P_succ_3d)

#     with open(f'checkpoint_det_{relay_num}_relay.pkl', 'rb') as f:
#         P_det_3d = pickle.load(f)

#     # Define these globally or pass them in
#     P_x_range = np.array(range(P_x_start * 10, P_x_end * 10 + 1)) / 10
#     P_u_range = np.array(range(P_u_start * 10, P_u_end * 10 + 1)) / 10

#     Z_out = np.array(P_outage_3d)
#     Z_det = np.array(P_det_3d)
#     Z_flat = np.full_like(Z_out, 0.1)

#     mask_high = (Z_flat > Z_out) & (Z_flat > Z_det)
#     mask_low = (Z_flat < Z_out) & (Z_flat < Z_det)
#     highlight_mask = mask_high | mask_low

#     # Extract valid P_x ranges for each P_u
#     intersection_ranges = {}

#     for j, P_u_val in enumerate(P_u_range):
#         valid_p_x = P_x_range[highlight_mask[:, j]]
#         if valid_p_x.size > 0:
#             intersection_ranges[P_u_val] = (valid_p_x.min(), valid_p_x.max())
#         else:
#             intersection_ranges[P_u_val] = None  # or (None, None)

#     return intersection_ranges

# relay_nums = [5, 10, 20, 30]
# colors = ['skyblue', 'lightgreen', 'salmon', 'plum']
# line_colors = ['blue', 'green', 'red', 'purple']

# plt.figure(figsize=(10, 6))

# for i, relay_num in enumerate(relay_nums):
#     intersection_ranges = calculate_intersection_ranges(relay_num)

#     P_u_vals = []
#     lower_bounds = []
#     upper_bounds = []

#     for P_u, bounds in intersection_ranges.items():
#         if bounds is not None:
#             P_u_vals.append(P_u)
#             lower_bounds.append(bounds[0])
#             upper_bounds.append(bounds[1])

#     # Sort in case unordered
#     sorted_indices = sorted(range(len(P_u_vals)), key=lambda k: P_u_vals[k])
#     P_u_vals = [P_u_vals[j] for j in sorted_indices]
#     lower_bounds = [lower_bounds[j] for j in sorted_indices]
#     upper_bounds = [upper_bounds[j] for j in sorted_indices]

#     label_prefix = f"{relay_num} relays"
#     plt.plot(P_u_vals, lower_bounds, label=f'{label_prefix} - Lower', color=line_colors[i], linestyle='--')
#     plt.plot(P_u_vals, upper_bounds, label=f'{label_prefix} - Upper', color=line_colors[i])
#     plt.fill_between(P_u_vals, lower_bounds, upper_bounds, color=colors[i], alpha=0.3)

# plt.title('Valid $P_x$ Ranges per $P_u$ for Different Relay Numbers')
# plt.xlabel('$P_u$')
# plt.ylabel('$P_x$')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %%
# for rn in [5, 10, 20, 30]:
#     calculate_intersection(rn)

# %% [markdown]
# Effect of adding extra relays:
# - For outage probability: $Prob\{outage\}_{E2E} = Prob\{every\ relay\ failed\}$ <br>
# Let p be the probability that a relay fails (assuming the probability is roughly equal for each relay) ($0 \leq p \leq 1$) <br>
# $\Rightarrow$ For each added relay, the E2E outage probability changes: $p^n -> p^{n+1}$
